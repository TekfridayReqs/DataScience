# %% [markdown]
# # Credit Risk Modelling Assessment — start here
#
# Welcome. Your tasks are in **`credit-model-assessment-questions.md`** in this folder.
#
# The dataset is at `/home/jovyan/data/credit_risk_dataset.csv`.
#
# You may work in **Python or R**. This notebook uses the Python kernel; to use R, open a new notebook (`File -> New -> Notebook`) and pick the **R** kernel. A Python and an R loading snippet are both shown below.
#
# Create as many notebooks as you like. Save your work as you go — it persists in your `work` folder.

# %%
import pandas as pd

df = pd.read_csv('/home/jovyan/data/credit_risk_dataset.csv')
print('Shape:', df.shape)
df.head()

# %% [markdown]
# ### Loading the data in R
#
# In an R notebook, the equivalent is:
#
# ```r
# df <- read.csv('/home/jovyan/data/credit_risk_dataset.csv')
# str(df)
# head(df)
# ```
